# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
import re
import math
import numpy
import pandas as pd 

import json
import csv
from itertools import chain
from typing import List
from multiprocessing.dummy import Pool as ThreadPool

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def make_df_with_float_salary(data):
    for i in range(len(data) - 1):
        data[i][2] = data[i][2].replace('от ', '').replace('до ', '').replace('.', '').split(' руб ')
    with_salary = [r for r in data if len(r[2]) == 2]
    with_float_salary = pd.DataFrame([[r[0], r[1], (1 if r[2][1] == 'на руки' else 0.8) * sum([int(el) for el in r[2][0].split(' ')]) / len(r[2][0].split(' ')) / 1000] for r in with_salary])
    with_float_salary = with_float_salary.sort_values(by=[2, 1])
    return with_float_salary

# %%
def make_df(city_abbr: str) -> pd.DataFrame:
    '''Returns a pd.DataFrame (vacancy url, adress, salary) of fulltime vacancies in 
       corresponding to the abbreviation city and export it to csv'''
    
    cities_dir = {'spb': 'Санкт-Петербург', 'smr': 'Самара', 'kzn': 'Казань', 'vdk': 'Владивосток'}
    
    with open(f'../hh-data/tables/{city_abbr}/fulltime/completed.csv') as file:
        data = [row.replace('\xa0', '').split('; ') for row in file.read().split('\n')]
    
    for i in range(len(data) - 1):
        data[i][2] = data[i][2].replace('от ', '').replace('до ', '').replace('.', '').split(' руб ')
    with_set_salary = [r for r in data if len(r[2]) == 2]
    df = pd.DataFrame([[r[0], 
                        f'{cities_dir[city_abbr]}, ' * (cities_dir[city_abbr] not in r[1]) + r[1], 
                        int((1 if r[2][1] == 'на руки' else 0.8) * sum([int(el) for el in r[2][0].split(' ')]) / len(r[2][0].split(' ')) / 1000)] for r in with_set_salary])
    df = df.sort_values(by=[2, 1])
    df.columns = ['url', 'adress', 'salary']
    df = df[df.salary > 0][df.salary <= 300]    
    df.to_csv(f'../hh-data/tables/{city_abbr}/fulltime/url-adress-salary.csv', index=False)
    return df

# %%
def plot_salaries(df, n=20):
    n, bins, patches = plt.hist(list(df['salary'])[20:], n, density=True, facecolor='g', alpha=0.75)

    plt.xlabel('Gpm')
    plt.ylabel('Probability')
    plt.grid(True)
    plt.axis([10, 300, 0, 0.03])
    plt.rcParams["figure.figsize"] = [11, 11]
    plt.show()

# %%
def plot_ln_of_salaries(df, n=20):
    n, bins, patches = plt.hist([math.log(a) for a in list(df['salary'])[20:]], n, density=True, facecolor='g', alpha=0.75)

    plt.xlabel('Gpm')
    plt.ylabel('Probability')
    plt.grid(True)

    plt.rcParams["figure.figsize"] = [11, 11]
    plt.show()

# %%
spb_df = make_df('spb')
# Out:
# /home/disa/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
spb_df
# Out:
#                                       url  \
# 7613   https://spb.hh.ru/vacancy/30707536
# 2667   https://spb.hh.ru/vacancy/30539353
# 6022   https://spb.hh.ru/vacancy/30388832
# 4276   https://spb.hh.ru/vacancy/30673196
# 877    https://spb.hh.ru/vacancy/30722524
# 5012   https://spb.hh.ru/vacancy/30407527
# 9227   https://spb.hh.ru/vacancy/30508993
# 4808   https://spb.hh.ru/vacancy/30586230
# 2089   https://spb.hh.ru/vacancy/30537883
# 9993   https://spb.hh.ru/vacancy/30584960
# 8283   https://spb.hh.ru/vacancy/30766667
# 8283                           Санкт-Петербург, Автово,       12
# 4714                 Санкт-Петербург, Василеостровская,       12
# 7937                    Санкт-Петербург, Гостиный двор,       12
# 7529   Чернышевская, Санкт-Петербург, улица Короленко, 7      12
# 3409   Чернышевская, Санкт-Петербург, улица Смольного, 3      12
# 9022   Академическая, Санкт-Петербург, Светлановский ...      13
# 170    Ладожская, Санкт-Петербург, Индустриальный про...      13
# 3953   Ладожская, Санкт-Петербург, Латышских Стрелков...      13
# 7080      Приморская, Санкт-Петербург, 6-линия В.О. , 57      13
# 3188                    Санкт-Петербург, Гостиный двор,       13
# 9771                    Санкт-Петербург, Гостиный двор,       13
# 1306                    Санкт-Петербург, Международная,       13
# 2933   Международная, Санкт-Петербург, Софийская улиц...      14
# 10006  Озерки, Санкт-Петербург, проспект Луначарского...      14
# 5203                     Санкт-Петербург, Бухарестская,       14
# 3419                    Санкт-Петербург, Гостиный двор,       14
# 6272                    Санкт-Петербург, Гостиный двор,       14
# 7883                    Санкт-Петербург, Гостиный двор,       14
# 8741                    Санкт-Петербург, Гостиный двор,       14
# 4145                          Санкт-Петербург, Купчино,       14
# ...                                                  ...     ...
# 1279   Фрунзенская, Санкт-Петербург, Московский просп...     200
# 1076   Чернышевская, Санкт-Петербург, Литейный проспе...     200
# 7533   Чернышевская, Санкт-Петербург, Литейный проспе...     200
# 1444   Чкаловская, Санкт-Петербург, улица Красного Ку...     200
# 2466                Санкт-Петербург, Площадь Восстания,      205
# 5656   Ладожская, Санкт-Петербург, проспект Энергетик...     206
# 5745   Адмиралтейская, Санкт-Петербург, Невский просп...     210
# 327    Санкт-Петербург, Улица Дыбенко, деревня Кудров...     220
# 431     Беговая, Санкт-Петербург, 3 линия, метро Беговая     225
# 1940   Елизаровская, Санкт-Петербург, проспект Обухов...     235
# 5274   Петроградская, Санкт-Петербург, Кантемировская, 2     239
# 5374   Петроградская, Санкт-Петербург, Кантемировская, 2     239
# 5466   Петроградская, Санкт-Петербург, Кантемировская, 2     239
# 4462   Василеостровская, Санкт-Петербург, 9-я линия В...     240
# 1042   Выборгская, Санкт-Петербург, Большой Сампсоние...     240
# 7600   Выборгская, Санкт-Петербург, Большой Сампсоние...     240
# 5582   Ладожская, Санкт-Петербург, Латышских Стрелков...     240
# 497       Горьковская, Санкт-Петербург, улица Чапаева, 9     250
# 3566         Международная, Санкт-Петербург, Южное шоссе     250
# 6024   Санкт-Петербург, Деловой центр, Москва, Пресне...     250
# 1776         Санкт-Петербург, Технологический институт,      250
# 1652                     Сенная площадь, Санкт-Петербург     250
# 1448   Старая Деревня, Санкт-Петербург, Стародеревенс...     250
# 6244   Технологический институт, Санкт-Петербург, 1 л...     250
# 4493                      Санкт-Петербург, Горьковская,      272
# 6887                      Санкт-Петербург, Горьковская,      272
# 409    Ладожская, Санкт-Петербург, Латышских Стрелков...     280
# 195                          Санкт-Петербург, Нарвская,      280
# 5524                   Санкт-Петербург, Площадь Ленина,      280
# 1765   Площадь Ленина, Санкт-Петербург, улица Комсомо...     300
#
# [10276 rows x 3 columns]

# %%
# Out:
# 1.2
